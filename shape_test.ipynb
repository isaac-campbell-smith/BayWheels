# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
fp = 'City_Boundaries/City_Boundaries.shp'

map_df = gpd.read_file(fp)

map_df.plot()

# %%
df = pd.read_csv()
